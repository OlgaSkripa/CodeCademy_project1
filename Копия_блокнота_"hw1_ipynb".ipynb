# %% [markdown]
# <a href="https://colab.research.google.com/github/OlgaSkripa/CodeCademy_project1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22hw1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание 1

# %% [markdown]
# Важный комментарий: **назовите** файл решения так, чтобы преподаватель **понимал**, кто сделал его.
#
# Большое спасибо и успехов :)

# %% [markdown]
# <center>
# <img src="https://meme-generator.com/wp-content/uploads/mememe/2019/11/mememe_cb8e239ef97eb73a7d04ecf46ed4bf5c-1.jpg" alt="YOU-ROCK" width="500" height="300">
# </center>

# %% [markdown]
# ## Задача 1

# %% [markdown]
# Напишите программу, которая спрашивает имя пользователя и выводит:
#
# "Привет, [имя]! Рад тебя видеть!"

# %%
name = input("Как тебя зовут? ")
print(f"Привет, {name}! Рад тебя видеть!")
# Out:
# Как тебя зовут? Ольга
# Привет, Ольга! Рад тебя видеть!

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Пользователь вводит число. Определите, чётное оно или нет, и выведите ответ. Предпочтительнеее сделать задачу в одну или две строчки.

# %%
print('четное' if int(input('Введите число: '))%2==0 else 'нечетное')
# Out:
# Введите число: 5
# нечетное

# %% [markdown]
# ## Задача 3

# %% [markdown]
# Напишите функцию, которая считает количество гласных букв (a, e, i, o, u) в строке.

# %%
def vowels(str):
  return sum(1 for char in str.lower() if char in 'aeiou')

print(f'In your string {vowels(input("Input a string: "))} vowels')
# Out:
# Input a string: ;aoiaodajmOIASD
# In your string 9 vowels

# %% [markdown]
# ## Задача 4

# %% [markdown]
# Создайте класс Point с координатами x и y. Добавьте метод для вычисления расстояния до другой точки. Посчитайте расстояние между Point(3, 4) и Point(0, 0).

# %%
import math
class Point:
  def __init__(self,x,y):
    self.x = x
    self.y = y

  def distance(self,other):
    return math.sqrt((self.x-other.x)**2+(self.y-other.y)**2)

p1=Point(3,4)
p2=Point(0,0)
print(p1.distance(p2))
# Out:
# 5.0

# %% [markdown]
# <h1>
# <b>
# <font color='red'>
# Следующая часть (numpy и pandas) должна быть выполнена без использования python циклов.
# </font>
# </b>
# </h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_breast_cancer
# The breast cancer Wisconsin dataset (classification)

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Создайте массив из 20 случайных чисел от 0 до 100 и оставьте только чётные.

# %%
r_array = np.random.randint(0,101,size=20)
print(r_array[r_array%2==0])
# Out:
# [68 78 76 68 88 48 86 68]

# %% [markdown]
# ## Задача 6

# %% [markdown]
# Создайте массив из 10 случайных чисел от 0 до 10. Найдите все уникальные элементы и их количество.

# %%
array_10 = np.random.randint(0,11,10)
print(array_10)
print(np.unique(array_10))
print(np.unique_counts(array_10))
# Out:
# [1 2 8 6 9 9 7 6 7 1]
# [1 2 6 7 8 9]
# UniqueCountsResult(values=array([1, 2, 6, 7, 8, 9]), counts=array([2, 1, 2, 2, 1, 2]))

# %% [markdown]
# ## Задача 7

# %% [markdown]
# Создайте массив из 10 случайных чисел от -10 до 10. Замените все отрицательные числа в массиве на 0.

# %%
array_10_10 = np.random.randint(-10,11,10)
print(array_10_10)
array_10_10[array_10_10<0]=0
print(array_10_10)
# Out:
# [ -5   8   3   3   5   3  -2   7 -10   6]
# [0 8 3 3 5 3 0 7 0 6]

# %% [markdown]
# ## Задача 8

# %%
# Про датасет для 8-10 заданий можно чуть детальнее прочитать тут:
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_breast_cancer.html

# Также можете прочитать в интернете про данный датасет.

# %% [markdown]
# Загрузите датасет load_breast_cancer с такими параметрами: return_X_y=False и as_frame=True. Получите список колонок в данном датасете (в читаемом формате,  это важно).
#
# Также получите процентное соотношение чисел в целевой переменной (переменная target, там два класса, то есть 0 и 1).

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer(return_X_y=False, as_frame=True)
print(data.feature_names)
print(round(data.target.sum()*100/len(data.target),2),"%  / ",round((len(data.target)-data.target.sum())*100/len(data.target),2),"%")
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']
# 62.74 %  /  37.26 %

# %% [markdown]
# ## Задача 9

# %% [markdown]
# Постройте гистограмму в seaborn для переменной 'mean area' с hue в качестве целевой переменной и добавьте параметр kde=True.
#
# Постройте диаграмму рассеяния в seaborn для переменных 'mean radius' (это x) и 'mean texture' (это y) с hue в качестве целевой переменной.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.histplot(data = data.frame,x = 'mean area', hue = 'target',kde = True,ax = axes[0])
sns.scatterplot(data = data.frame, x='mean radius', y = 'mean texture', hue = 'target', ax = axes[1])
plt.show()

# %% [markdown]
# ## Задача 10

# %% [markdown]
# Постройте через тепловую карту матрицу корреляции для первых десяти переменных.

# %%
df = data.frame
df_first_10 = df.iloc[:,:10]
plt.figure(figsize = (12,10))
sns.heatmap(df_first_10.corr(numeric_only=True),annot = True, fmt = ".2f", square = True)
plt.show()
